# %%
import sklearn
from sklearn import preprocessing

# %%
Letter_Labels = preprocessing.LabelEncoder()

# %%
#LabelEncoding all Hindi letters......

# %%
Hindiletters=[      ' ',
    
    
    
    'अ','आ','इ','ई','उ','ऊ','ए','ऐ','ओ','औ','अं','अः',
                                               
                           'ऋ',
               
                  'क','ख','ग','घ','ङ',
                  'च','छ','ज','झ','ञ',
                  'ट','ठ','ड','ढ','ण',
                  'त','थ','द','ध','न',
                  'प','फ','ब','भ','म',
                  'य','र','ल','व',
                  'श','ष','स','ह'
                  'क्ष','त्र','ज्ञ','ऋ','श्र',
             
             
             
             
             'का','क','क','कु','कू','कृ','के','कै','को','कौ','कं','क:',
             
             'खा','ख','खी','खु','खू','खे','खै','खो','खौ','खं','ख:',
             
             'गा','ग','गी','गु','गू','गृ','गे','गै','गो','गौ','गं','ग:',
             
             'घा','घ','घी','घु','घू','घृ','घे','घै','घो','घौ','घं','घ:',
             
             
             'चा','च','ची','चु','चू','चे','चै','चो','चौ','चं','च:',
             
            'छा','छ','छ','छु','छ','छे','छै','छो','छौ','छं','छ:',
             
             'जा','जि','जी','जु','ज','जे','जै','जो','जौ','जं','ज:',
             
             'झा','झ','झी','झु','झ','झे','झै','झो','झौ','झं','झ:',
             
             'टा','ट','ट','टु','ट','टे','टै','टो','टौ','टं','ट:',
             
             'ठा','ठ','ठ','ठु','ठू','ठे','ठै','ठो','ठौ','ठं','ठ:',
             
             'डा','ड','डी','डु','डू','डे','डै','डो','डौ','डं','ड:',
             
            'ढा','ढ','ढ','ढु','ढ','ढे','ढै','ढो','ढ','ढं','ढ:',
             
             'ता','त','ती','तु','तू','तृ','ते','तै','तो','तौ','तं','त:',

             'था','थ','थी','थु','थू','थे','थै','थो','थौ','थं','थ:',
             
             'दा','द','द','दु','दू','दे','दै','दो','दौ','दं','द:', 
             
             'धा','ध','धी','धु','धू','धृ','धे','धै','धो','धौ','धं','ध:',
             
             'ना','न','नी','नु','नू','नृ','ने','नै','नो','नौ','नं','न:',
             
             'पा','प','पी','पु','पू','पृ','पे','पै','पो','पौ','पं','प:',

             
            'फा','प','फ','फु','फू','फे','फै','फो','फौ','फं','फ:',
             
             'बा','ब','बी','बु','बू','बृ','बे','बै','बो','बौ','बं','ब:',
             
            'भा','भ','भी','भु','भू','भृ','भे','भै','भो','भौ','भं','भ:',
             
             'मा','म','मी','मु','मू','मृ','मे','मै','मो','मौ','मं','म:',
             
             'या','य','यी','यु','यू','ये','यै','यो','यौ','यं','य:',
              
              'रा','र','र','रु','रू','रे','रै','रो','रौ','रं','र:',
             
            'ला','ल','ल','लु','लू','लृ','ले','लै','लो','लौ','लं','ल:',
             
             'वा','व','वी','वु','वू','वृ','वे','वै','वो','वौ','वं','व:',

'षा','ष','षी','षु','षू','षृ','षे','षै','षो','षौ','षं','ष:',
              
              'सा','स','सी','सु','सू','सृ','से','सै','सो','सौ','सं','स:',
              
'हा,हि','ही','हु','हू','हे','है','हो','हौ','हं','हः',
              
              
            'क्ष','क्षा','क्षि','क्षी','क्षु','क्षू','क्षे','क्षै','क्षो','क्षौ','क्षं','क्षः',
              
              
              'ज्ञ','ज्ञा','ज्ञि','ज्ञी','ज्ञु','ज्ञू','ज्ञे','ज्ञै','ज्ञो','ज्ञौ','ज्ञं','ज्ञः',
              
              
              'त्र','त्रा','त्रि','त्री','त्रु','त्रू','त्रे','त्रै','त्रो','त्रौ','त्रं','त्रः',

              'ज्ञ','ज्ञा','ज्ञि','ज्ञी','ज्ञु','ज्ञू','ज्ञे','ज्ञै','ज्ञो','ज्ञौ','ज्ञं','ज्ञः'
              ]

# %%
len(Hindiletters)
# Out:
# 431

# %%
Letter_Labels.fit_transform(Hindiletters)
# Out:
# array([  0,   1,   4,   5,   6,   7,   8,  10,  11,  12,  13,   2,   3,
#          9,  14,  37,  48,  60,  72,  73,  84,  93, 116, 126, 127, 136,
#        146, 157, 165, 166, 190, 201, 211, 223, 235, 247, 257, 269, 281,
#        293, 304, 314, 325, 337, 339, 351, 365, 178, 104,   9, 338,  17,
#         14,  14,  18,  19,  20,  21,  22,  23,  24,  16,  15,  40,  37,
#         41,  42,  43,  44,  45,  46,  47,  39,  38,  51,  48,  52,  53,
#         54,  55,  56,  57,  58,  59,  50,  49,  63,  60,  64,  65,  66,
#         67,  68,  69,  70,  71,  62,  61,  76,  73,  77,  78,  79,  80,
#         81,  82,  83,  75,  74,  87,  84,  84,  88,  84,  89,  90,  91,
#         92,  86,  85,  96,  97,  98,  99,  93, 100, 101, 102, 103,  95,
#         94, 119, 116, 120, 121, 116, 122, 123, 124, 125, 118, 117, 130,
#        127, 127, 131, 127, 132, 133, 134, 135, 129, 128, 139, 136, 136,
#        140, 141, 142, 143, 144, 145, 138, 137, 149, 146, 150, 151, 152,
# ...

# %%
x='विभाग की किसी भी प्रकार की जानकारी के लिए और अगर आप की कोई सूचना देना चाहते हैं तो कृपया इस ईमेल पर संपर्क कीजिए'

# %%
x[0]
# Out:
# 'व'

# %%
x[1]
# Out:
# 'ि'

# %%
x[2]
# Out:
# 'भ'

# %%
x[3]
# Out:
# 'ा'

# %%
x=['का','क','क','कु','कू','कृ','के','कै','को','कौ','कं','क:']

# %%
len(x)
# Out:
# 12

# %%
x[1]
# Out:
# 'क'
